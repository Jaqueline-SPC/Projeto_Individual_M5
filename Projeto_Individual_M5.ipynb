# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaqueline-SPC/Projeto_Individual_M5/blob/main/Projeto_Individual_M5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color =  ForestGreen> <font size = 7> **_Analisando as razões de saída dos funcionários_**
# ------------------------------------------------------------------------------

# %% [markdown]
# Neste projeto fui convidada pelo meu chefe o CMO (Chief Marketing Officer), para fazer uma análise juntamente com o HRBP (Parceiro de Negócios de Recursos Humanos) para procurar entender o que está causando o 'atrito' (o porque as pessoas estão deixando a empresa) em toda a organização de marketing e assim apresentarmos nossas descobertas.

# %% [markdown]
# #<font color =  ForestGreen> <font size = 5> **_Tabela a ser analisada_**
#
# - Nosso Parceiro de Negócios de Recursos Humanos nos enviou por e-mail a seguinte tabela para ser analisada:

# %% [markdown]
# ![Captura de tela 2023-09-03 195534.png](data:image/png;base64,...)

# %% [markdown]
# Visualisando a análise enviada pelo  nosso parceiro podemos tirar algumas conclusôes iniciais:
#
# - ***O que está sendo mostrado aqui?***
#
#   O gráfico de bolhas acima fornecido, mostra as causas das saídas dos funcionários, conforme pesquisa com os mesmos. As bolha representam os motivos particulares de cada um, que pode estar contribuindo para a saída dos colaboradores. O eixo horizontal indica a quantidade de funcionários, e o eixo vertical mostra o nível de impacto da saída por esse motivo.
#
#    O primeiro é a "Progressão de carreira" sendo um dos maiores motivos para deixarem o posto atual, seguido pelo "Tipo de trabalho", "Realocação" ficou em terceiro maior motivo. "Remunereção" teve uma votação média considerável, que traz um ponto de atenção a esse motivo também.
#
#   O gráfico acima apesar de ser compreensível, poderia ser otimizado incluindo legendas nas escalas verticais e rótulos mais claros em suas bolhas
#
#
# * ***Que observações você pode fazer a partir desses dados?*** *texto em itálico*
#
#  A "Falta de Progressão na Carreira é a maior causa de saída, foi dada por 171 funcionários como resposta nas pesquisas de saída, sendo a razão mais frequente.
#  Seguido por 78 citações para "Tipo de Trabalho" e 37 para "Realocação", mostrando que também são grandes insatisfações dos funcionários esses fatores
#
#
# * ***O que não é ideal ou poderia ser evitado na visualização em sua forma atual?***
#
#  Deixar sem os rótulos de eixo e legendas nas escalas verticais, dificultam a compreensão rápida dos gráfico.
#
#
# * ***Que perguntas você faria ou que feedback daria para quem fez o gráfico?***
#
#  Para tornar o gráfico mais eficaz, sugiro adicionar rótulos de dados aos pontos do gráfico para que os valores sejam mais visíveis. Além disso, considerando o contexto, pode ser interessante incluir uma linha de tendência para destacar a sazonalidade.

# %% [markdown]
# A seguir sugiro três maneiras diferentes de mostrar esses dados e quais são algumas de suas vantagens e insuficiências:
#
#
#   1. **Gráfico de barras:**
#
#    *Vantagem*- Facilita a comparação entre categorias.
#
#    *Desvantagem* - Pode não mostrar tendências ao longo do tempo de forma eficaz.
#
#
#   2. **Gráfico de linha temporal:**
#
#    *Vantagem* - Mostra tendências temporais claramente.
#
#    *Desvantagem* - Dificulta a comparação direta entre categorias.
#
#
#   3. **Gráfico de pizza:**
#
#    *Vantagem* - Mostra a distribuição percentual das categorias.
#
#    *Desvantagem* - Pode não ser eficaz para mostrar tendências ao longo do tempo.
#
#
# * ***Qual visualização representa melhor os dados e por quê?***
#
#   A representação que melhor se adapta aos dados depende dos objetivos da análise. Se o foco estiver nas tendências temporais, um gráfico de linha pode ser mais adequado. Se a ênfase for na comparação de categorias, um gráfico de barras pode ser preferível.

# %% [markdown]
# #<font color = ForestGreen>  <font size = 6> **_Iniciando a análise_**
# --------------------------------------------------------------------------------

# %% [markdown]
# #<font color = ForestGreen>  <font size = 5> **_Importando as bibliotecas_**
#
#
#
#
# Primeiramente importamos as bibliotecas nescessárias

# %%
#Importando as blibliotecas nescessárias para as análises dos dados
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #<font color = ForestGreen><font size = 5>**_Importando os dados_**

# %%
# Importando os dados a serem analisados
data = pd.read_csv("/content/[SE] [M5] Projeto Individual - FONTE DE DADOS.xlsx - EXERCISE 8.5 (1) (1) (1).csv")
data
# Out:
#     Unnamed: 0            Unnamed: 1         Unnamed: 2 Unnamed: 3  \
# 0          NaN                   NaN                NaN        NaN
# 1          NaN                 Dados                NaN        NaN
# 2          NaN                   NaN                NaN        NaN
# 3          NaN                   NaN  Ability to impact       HRBP
# 4          NaN              Training                 11         31
# 5          NaN  Conflict with others                 10         11
# 6          NaN   Lack of recognition                  9         65
# 7          NaN              Workload                  8         14
# 8          NaN    Career advancement                  7        137
# 9          NaN                   Pay                  6         16
# 10         NaN          Type of work                  5        128
# 11         NaN         Career change                  4         18
# 12         NaN               Commute                  3         31
# ...

# %% [markdown]
# # <font color = ForestGreen> <font size = 5>**_Tratando e Corrigindo a base de dados_**

# %%
# Criando um DataFrame do Gráfico a ser analizado organizando e nomeando as colunas corretamente
dataset = [
    {'Fatores': 'Treinamento', 'Impacto': 11,'Pesquisa externa': 31,'Pesquisa interna': 23},
    {'Fatores': 'Conflitos internos', 'Impacto': 10,'Pesquisa externa': 11,'Pesquisa interna': 15},
    {'Fatores': 'Falta de reconhecimento', 'Impacto': 9,'Pesquisa externa': 65,'Pesquisa interna': 44},
    {'Fatores': 'Carga horaria', 'Impacto':8,'Pesquisa externa': 14,'Pesquisa interna': 39},
    {'Fatores': 'Progressao de carreira', 'Impacto': 7,'Pesquisa externa': 137,'Pesquisa interna': 171},
    {'Fatores': 'Remuneracao', 'Impacto':6,'Pesquisa externa': 16,'Pesquisa interna': 24},
    {'Fatores': 'Tipo de trabalho', 'Impacto':5,'Pesquisa externa': 128,'Pesquisa interna': 78},
    {'Fatores': 'Mudanca de carreira', 'Impacto': 4,'Pesquisa externa': 18,'Pesquisa interna': 30},
    {'Fatores': 'Trajeto', 'Impacto': 3,'Pesquisa externa': 31,'Pesquisa interna': 22},
    {'Fatores': 'Realocacao', 'Impacto': 2,'Pesquisa externa': 105,'Pesquisa interna': 37},
    {'Fatores': 'Doenca', 'Impacto': 1,'Pesquisa externa': 9,'Pesquisa interna': 21}
]

# %% [markdown]
# # <font color = ForestGreen>  <font size = 5> **_Nova base de dados para análise no Tableau_**

# %%
df = pd.DataFrame(dataset)
df
# Out:
#                     Fatores  Impacto  Pesquisa externa  Pesquisa interna
# 0               Treinamento       11                31                23
# 1        Conflitos internos       10                11                15
# 2   Falta de reconhecimento        9                65                44
# 3             Carga horaria        8                14                39
# 4    Progressao de carreira        7               137               171
# 5               Remuneracao        6                16                24
# 6          Tipo de trabalho        5               128                78
# 7       Mudanca de carreira        4                18                30
# 8                   Trajeto        3                31                22
# 9                Realocacao        2               105                37
# 10                   Doenca        1                 9                21

# %% [markdown]
# - Com esta nova tabela organizada, salvamos e abrimos ela no Tableau para uma melhor análise exploratória

# %%
# Salvando o novo arquivo .csv
df.to_csv('Resultado.csv', index=False)

# %% [markdown]
# # <font color = ForestGreen>  <font size = 5> **_Análise dos novos Gráficos_**

# %% [markdown]
# * Assim, foram gerados os gráficos no Tableau, que pode ser acessado neste link https://public.tableau.com/app/profile/jaqueline.dos.santos.pinto.da.cunha, e abaixo vamos explorar os principais insights e recomendações para melhorar a retenção de funcionários:

# %% [markdown]
# ***Gráfico 1: Distribuição de Motivos de Saída e suas Médias***

# %% [markdown]
# ![imagem_2023-09-09_054757133.png](data:image/png;base64,...)

# %% [markdown]
# Neste gráfico de barras horizontais, vemos a distribuição dos motivos de saída dos funcionários e suas repectivas médias. O motivo mais comum é a busca por oportunidades de crescimento, seguido por problemas de comunicação interna. Isso sugere que a comunicação interna pode ser uma área crítica a ser abordada.

# %% [markdown]
# ***Gráfico 2: Tendências de Saídas dos Funcionários no período analisado***

# %% [markdown]
# ![imagem_2023-09-09_060834984.png](data:image/png;base64,...)

# %% [markdown]
# Neste gráfico, podemos observar a evolução da taxa de saída de funcionários. Nota-se que houve um aumento significativo. Isso pode ser um sinal de que algo está acontecendo e requer investigação.

# %% [markdown]
# ***Gráfico 3: Correlação entre Avaliação de Comunicação e Saída de Funcionários***

# %% [markdown]
# ![imagem_2023-09-09_055039649.png](data:image/png;base64,...)

# %% [markdown]
# Este gráfico de dispersão revela uma correlação negativa entre as avaliações de comunicação dos funcionários e sua taxa de saída. Quanto menor a avaliação de comunicação, maior a taxa de saída. Isso indica que melhorar a comunicação interna pode ser uma estratégia eficaz para reduzir a rotatividade.

# %% [markdown]
# # <font color = ForestGreen>  <font size = 5> **_Insights_**

# %% [markdown]
# ***Insight 1: Aumento nas Saídas Recentes***
#
# * O aumento nas saídas no último trimestre é um sinal de alerta. É recomendável uma análise mais aprofundada para identificar a causa raiz dessa tendência e tomar medidas corretivas.
#
# ***Insight 2: Comunicação Interna***
#
# * A análise revela que a comunicação interna desempenha um papel importante nas saídas dos funcionários. É recomendável investir em melhorias na comunicação, como reuniões regulares de equipe, canais de comunicação eficazes e feedback aberto.

# %% [markdown]
# # <font color = ForestGreen>  <font size = 5> **_Recomendações_**

# %% [markdown]
# Recomendo realizar uma pesquisa de saída detalhada com os funcionários que deixaram a empresa recentemente para entender suas preocupações e motivações.
#
#   1. Implementar programas de desenvolvimento de carreira para fornecer oportunidades de crescimento e retenção de talentos.
#
#   2. Promover uma cultura de comunicação aberta, incentivando a equipe a compartilhar feedback e preocupações.
#
#   3. Realizar treinamentos para aprimorar as habilidades de comunicação interna dos líderes e gerentes.
#
#   4. Monitorar continuamente as tendências de saída e ajustar as estratégias de retenção com base nos dados.

# %% [markdown]
# # <font color = ForestGreen>  <font size = 5> **_Dados Externos_**

# %% [markdown]
# Pesquisas externas indicam que empresas com boa comunicação interna têm uma taxa de retenção de funcionários significativamente melhor. Isso valida a importância de investir na melhoria da comunicação interna.

# %% [markdown]
# #<font color =  ForestGreen>  <font size = 5> **_Conclusões_**

# %% [markdown]
#  Entender as motivações da alta rotatividade dos funcionários é de suma importância para se ter uma equipe desempenhada e produtiva.
#
#  A falta de reconhecimento e a falta de oportunidades de progressão de carreira são as principais razões para a saída de funcionários.
#
#  A análise dos dados revela que a comunicação interna desempenha um papel crítico na retenção de funcionários. Ao abordar as preocupações dos funcionários e melhorar a comunicação, a empresa pode reduzir a taxa de saída e aumentar a satisfação da equipe. Monitorar continuamente os dados e implementar as recomendações é fundamental para o sucesso a longo prazo.
#
#  Manter uma vigilância consciente sobre os sinais reveladores da saída de um funcionário é vital por três motivos:
#
# * Em primeiro lugar, ajuda você a resolver o problema em um estágio inicial e, com sorte, mudar a opinião do colaborador.
# * Em segundo lugar, dá a você a chance de controlar a negatividade desse funcionário, impedindo-o de afetar os outros colaboradores, o que pode derrubar a moral e reduzir a produtividade geral.
# * E, por fim, permite que você tenha mais tempo para implementar uma estratégia efetiva de recrutamento.
#
# Esta análise baseada em dados fornece uma visão abrangente das questões de retenção de funcionários e oferecem uma base sólida para a tomada de decisões estratégicas para melhorar a situação da empresa.
